# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import os

db_path = "/Users/travisthompson/REPOS/FFPlayground/FFLPlayground.db"
con = sqlite3.connect(db_path)

# %%
analytics_path = "/Users/travisthompson/REPOS/FFPlayground/src/sql/analytics"
analytic = "lifetime_points_for_against.sql"

with open(os.path.join(analytics_path, analytic), "r") as f:
    query = f.read()
    
df = pd.read_sql(query, con=con)

# %%
plt.scatter(x=df["TotalPointsFor"], y=df["TotalPointsAgainst"])
